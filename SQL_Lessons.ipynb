# %%
# !conda install -y sqlalchemy psycopg2-binary pandas
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - defaults
# Platform: linux-64
# ...
# Solving environment: failed
#
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - psycopg2-binary
#
# Current channels:
#
#   - defaults
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
# !pip install psycopg2-binary sqlalchemy pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 30.5 MB/s eta 0:00:00 0:00:01
# ...

# %%
from sqlalchemy import create_engine
import pandas as pd
DATABASE_URI = 'postgresql://postgres:3420Yadkin!@localhost:5432/microbiome_db'
engine = create_engine(DATABASE_URI)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       2 import pandas as pd
#       3 DATABASE_URI = 'postgresql://postgres:3420Yadkin!@localhost:5432/microbiome_db'
# ----> 4 engine = create_engine(DATABASE_URI)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/sqlalchemy/util/deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# ...

# %%
# !pip install psycopg2-binary
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...

# %%
from sqlalchemy import create_engine
import pandas as pd

DATABASE_URI = 'postgresql://postgres:3420Yadkin!@localhost:5432/microbiome_db'
engine = create_engine(DATABASE_URI)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 5
#       2 import pandas as pd
#       4 DATABASE_URI = 'postgresql://postgres:3420Yadkin!@localhost:5432/microbiome_db'
# ----> 5 engine = create_engine(DATABASE_URI)
#
# File <string>:2, in create_engine(url, **kwargs)
#
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/sqlalchemy/util/deprecations.py:281, in deprecated_params.<locals>.decorate.<locals>.warned(fn, *args, **kwargs)
#     274     if m in kwargs:
#     275         _warn_with_version(
#     276             messages[m],
#     277             versions[m],
#     278             version_warnings[m],
#     279             stacklevel=3,
#     280         )
# --> 281 return fn(*args, **kwargs)
#
# ...

# %%
import sys
print(sys.executable)
# Out:
# /opt/conda/envs/anaconda-2024.02-py310/bin/python

# %%
# %pip install psycopg2-binary
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in links: /usr/share/pip-wheels
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from sqlalchemy import create_engine
import pandas as pd

DATABASE_URI = 'postgresql://postgres:3420Yadkin!@localhost:5432/microbiome_db'
engine = create_engine(DATABASE_URI)

# %%
from sqlalchemy import create_engine
import pandas as pd

DATABASE_URI = 'postgresql://postgres:3420Yadkin!@192.168.86.1:5432/microbiome_db'
engine = create_engine(DATABASE_URI)

import pandas as pd
query = '''
SELECT samples.sample_id, samples.status, patients.patient_name, patients.age
From samples
Join patients ON samples.patient_id = patients.patient_id;'''
df = pd.read_sql_query(query, engine)
print(df)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3293, in Engine.raw_connection(self)
#    3272 """Return a "raw" DBAPI connection from the connection pool.
#    3273
#    3274 The returned object is a proxied version of the DBAPI
#    (...)
#    3291
#    3292 """
# -> 3293 return self.pool.connect()
#
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/sqlalchemy/pool/base.py:452, in Pool.connect(self)
# ...

# %%
from sqlalchemy import create_engine
import pandas as pd

DATABASE_URI = 'postgresql://postgres:3420Yadkin!@localhost:5432/microbiome_db'
engine = create_engine(DATABASE_URI)

import pandas as pd
query = '''
SELECT samples.sample_id, samples.status, patients.patient_name, patients.age
From samples
Join patients ON samples.patient_id = patients.patient_id;'''
df = pd.read_sql_query(query, engine)
print(df)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3293, in Engine.raw_connection(self)
#    3272 """Return a "raw" DBAPI connection from the connection pool.
#    3273
#    3274 The returned object is a proxied version of the DBAPI
#    (...)
#    3291
#    3292 """
# -> 3293 return self.pool.connect()
#
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/sqlalchemy/pool/base.py:452, in Pool.connect(self)
# ...

# %%
from sqlalchemy import create_engine
import pandas as pd

DATABASE_URI = 'postgresql://postgres:3420Yadkin!@localhost:5432/microbiome_db'
engine = create_engine(DATABASE_URI)

import pandas as pd
query = '''
SELECT samples.sample_id, samples.status, patients.patient_name, patients.age
From samples
Join patients ON samples.patient_id = patients.patient_id;'''
df = pd.read_sql_query(query, engine)
print(df)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3293, in Engine.raw_connection(self)
#    3272 """Return a "raw" DBAPI connection from the connection pool.
#    3273
#    3274 The returned object is a proxied version of the DBAPI
#    (...)
#    3291
#    3292 """
# -> 3293 return self.pool.connect()
#
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/sqlalchemy/pool/base.py:452, in Pool.connect(self)
# ...

# %%
from sqlalchemy import create_engine
import pandas as pd


DATABASE_URI = 'postgresql://postgres:3420Yadkin!@192.168.86.30:5432/microbiome_db'
engine = create_engine(DATABASE_URI)

query = '''
SELECT samples.sample_id, samples.status, patients.patient_name, patients.age
FROM samples
JOIN patients ON samples.patient_id = patients.patient_id;
'''

df = pd.read_sql_query(query, engine)
print(df)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3293, in Engine.raw_connection(self)
#    3272 """Return a "raw" DBAPI connection from the connection pool.
#    3273
#    3274 The returned object is a proxied version of the DBAPI
#    (...)
#    3291
#    3292 """
# -> 3293 return self.pool.connect()
#
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/sqlalchemy/pool/base.py:452, in Pool.connect(self)
# ...

# %%
import psycopg2
try:
    conn = psycopg2.connect(
        host="192.168.86.30",
        port=5432,
        database="microbiome_db",
        user="postgres",
        password="3420Yadkin!"
    )
    print("Connected successfully!")
except Exception as e:
    print("Failed to connect:", e)
# Out:
# Failed to connect: connection to server at "192.168.86.30", port 5432 failed: Connection refused
# 	Is the server running on that host and accepting TCP/IP connections?

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect("microbiome_db.sqlite")

conn.execute('''CREATE TABLE patients (patient_id INTEGER PRIMARY KEY AUTOINCREMENT, patient_name TEXT, age INTEGER, city TEXT);''')
conn.executemany('''INSERT INTO patients (patient_name, age, city) VALUES (?, ?, ?);
''', [ ('Alice Smith', 32, 'Seattle'),    ('Bob Johnson', 28, 'Boston'),    ('Carol Williams', 35, 'San Francisco'),    ('David Miller', 40, 'Chicago')
])
conn.execute('''CREATE TABLE samples (    sample_id INTEGER PRIMARY KEY AUTOINCREMENT,    collection_date TEXT,    status TEXT,    patient_id INTEGER,    FOREIGN KEY(patient_id) REFERENCES patients(patient_id));''')
conn.executemany('''INSERT INTO samples (collection_date, status, patient_id) VALUES (?, ?, ?);''', [    ('2025-03-18', 'processed', 1),    ('2025-03-19', 'pending', 2)])
conn.commit()
print("SQLite database created and populated successfully!")
# Out:
# SQLite database created and populated successfully!

# %%
query = '''
SELECT samples.sample_id, samples.status, patients.patient_name, patients.age
FROM samples
JOIN patients ON samples.patient_id = patients.patient_id;
'''

df = pd.read_sql_query(query, conn)
print(df)
# Out:
#    sample_id     status patient_name  age
# 0          1  processed  Alice Smith   32
# 1          2    pending  Bob Johnson   28

# %%
from sqlalchemy import create_engine
import pandas as pd
engine = create_engine('postgresql://tuartmith:3420Yadkin!@localhost:5432/microbiome_db')
df = pd.read_sql('SELECT version();', engine)
print(df)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/sqlalchemy/engine/base.py:145, in Connection.__init__(self, engine, connection, _has_events, _allow_revalidate, _allow_autobegin)
#     144 try:
# --> 145     self._dbapi_connection = engine.raw_connection()
#     146 except dialect.loaded_dbapi.Error as err:
#
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/sqlalchemy/engine/base.py:3293, in Engine.raw_connection(self)
#    3272 """Return a "raw" DBAPI connection from the connection pool.
#    3273
#    3274 The returned object is a proxied version of the DBAPI
#    (...)
#    3291
#    3292 """
# -> 3293 return self.pool.connect()
#
# File /opt/conda/envs/anaconda-2024.02-py310/lib/python3.10/site-packages/sqlalchemy/pool/base.py:452, in Pool.connect(self)
# ...
